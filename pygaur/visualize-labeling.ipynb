# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

# %% [markdown]
# ## Notebook to visualize the results of the semantic association task

# %%
fp_labels_json = "./data/mysql/expert-defined-tags/labels.json"
with open(fp_labels_json, 'r') as f:
    data = json.load(f)

actions = data['GENERAL']['tag_values']['actions']
objects = data['GENERAL']['tag_values']['objects']
